# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
import pandas as pd

df_plaquesize = pd.read_csv('MP1plaquesize.csv', header=None)*1000 #mm to micron
df_zoi = pd.read_csv('MP1ZOI.csv', header=None)*1000

# %%
size = 4
ftarr = np.linspace(1, 10, size)
fbarr = np.linspace(1, 10, size)
origin = "lower"
plt.imshow(df_zoi.T/1000, origin = origin)
plt.colorbar()
plt.xticks([0,1,2,3],ftarr)
plt.yticks([0,1,2,3],fbarr)
plt.xlabel(r"$f_{\tau}$" )
plt.ylabel(r"$f_{\beta}$")
plt.figure()
plt.imshow(df_plaquesize.T/1000, origin = origin)
plt.colorbar()
plt.xticks([0,1,2,3],ftarr)
plt.yticks([0,1,2,3],fbarr)
plt.xlabel(r"$f_{\tau}$" )
plt.ylabel(r"$f_{\beta}$")
plt.show()

# %%
df_plaquesize.T/1000
# Out:
#           0         1         2         3
# 0  0.954698  0.879195  0.879195  0.879195
# 1  0.969799  0.879195  0.879195  0.879195
# 2  0.979866  0.879195  0.879195  0.879195
# 3  0.988255  0.879195  0.879195  0.879195
