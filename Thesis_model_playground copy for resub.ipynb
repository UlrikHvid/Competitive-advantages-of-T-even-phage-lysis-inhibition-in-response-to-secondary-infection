# %%
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
from scipy.integrate import solve_ivp

from Broth_model import *
from Plaque_model import *
from Swimming_model import *
from Initial_values import *
from Plotters import *

# %% [markdown]
# # Broth model

# %%
#Fetch default parameter values 
V = DV() 

#Option to change parameter values (see Initial_values.py)
#V.f_tau = 10

#Fetch initial values 
y0 = IV("M1")

#Set simulation length (mins)
t = 20*V.tau0

#Run simulation
M1sol = solve_ivp(M1,[0,t],y0,args = Const(V,"M1"))

#Plot
BrothPlotter("M1",V,M1sol.t,M1sol.y, scale = "log",figtitle = "M1")

# %%
#Competition between wild type and r-mutant

V2 = DV() #Default values
V2.comp = 1 #Competition version

#Intial values
y0 = IV("M1",comp = V2.comp)

#Simulation length (mins)
t = 5*60 

M1Csol = solve_ivp(M1,[0,t],y0,args = Const(V2,"M1"))
BrothPlotter("M1",V2,M1Csol.t,M1Csol.y,figtitle = "M1C")

# %% [markdown]
# # Plaque model

# %%
#r-mutant plaque

VP = DVS(Rmax = 1.5*10**3,dr = 2) #Default values
y0 = IVS("MP0",VP) #Intial values
t = 5*60 #Simulation time
simP = MPShell("MP0",y0,VP,t)
# Out:
#   1%|          | 74201/11249999 [00:04<10:26, 17833.89it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[30], line 6
#       4 y0 = IVS("MP0",VP) #Intial values
#       5 t = 5*60 #Simulation time
# ----> 6 simP = MPShell("MP0",y0,VP,t)
#
# File ~/Documents/GitHub/Masters-thesis/Plaque_model.py:46, in MPShell(model, y0, V, t, frames, absorbing)
#      44     for i in tqdm(range(its)):
#      45         ynext = MP0(ynext,V,gn0,DMP,DMn)
# ---> 46         if i in frameind:
#      47             sim[np.where(frameind == i)] = ynext
#      48 elif model    == "MP1":
#
# KeyboardInterrupt:

# %%
lastframe = simP[-1]
Btot  = np.sum(lastframe[:11], axis = 0)
B = lastframe[0]
rhalf = np.where(Btot > Btot[-1]/2)[0][0]*VP.dr/1000 #Convert to mm
rZOI = np.where(B > B[-1]/2)[0][0]*VP.dr/1000 #Convert to mm
rhalf,rZOI
# Out:
# (0.506, 0.62)

# %%
GifGenerator(simP,VP,t,"MP0",f"MP0",ylim = (0.001,20),legendloc = "upper right",Btot = True)

# %%
#Wild type plaque

VP2 = DVS(Rmax = 1.5*10**3,dr = 2)
y0 = IVS("MP1",VP2)
t = 5*60
simP2 = MPShell("MP1",y0,VP2,t)
# Out:
# 100%|██████████| 3374999/3374999 [06:45<00:00, 8314.87it/s]

# %%
lastframe2 = simP2[-1]
Btot2  = np.sum(lastframe2[:21], axis = 0)
B2  = lastframe2[0]
rhalf2 = (np.where(Btot2 > Btot2[-1]/2)[0][0])*VP2.dr/1000 #Convert to mm
rZOI2 = (np.where(B2 > B2[-1]/2)[0][0])*VP2.dr/1000 #Convert to mm
rhalf2/rhalf,rZOI2/rZOI
# Out:
# (0.4308300395256917, 0.6580645161290323)

# %%
rhalf2,rhalf
# Out:
# (0.218, 0.506)

# %%
GifGenerator(simP2,VP2,t,"MP1",f"MP1",ylim = (0.001,20),legendloc = "upper right",Btot = True)

# %% [markdown]
# # Swimming model

# %%
#r-mutant swimming plate

#Set parameters
rho = 4*1e6 #Richness of the swimming medium - has a large effect on the simulation outcome
VS = DVS(dr = 20,rho = rho,Rmax = 40*10**3)

#Default values
y0 = IVS("MS0",VS)

#Start simulation
t = 20*60
simS = MSShell("MS0",y0,VS,t)
# Out:
# 100%|██████████| 450000/450000 [13:27<00:00, 557.58it/s]

# %%
GifGenerator(simS,VS,t,"MS0",name = "MS0",ylim = (1e-5,50))

# %%
#Wild-type swimming plate

#Set parameters
rho = 4*1e6
VS2 = DVS(dr = 20,rho = rho,Rmax = 40*10**3)

#Default values
y0 = IVS("MS1",VS2)

#Start
t = 20*60
simS2 = MSShell("MS1",y0,VS2,t)
# Out:
# 100%|██████████| 450000/450000 [20:52<00:00, 359.17it/s]

# %%
GifGenerator(simS2,VS2,t,"MS1",name = "MS1",ylim = (1e-5,50))
